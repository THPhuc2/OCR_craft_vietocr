# %% [markdown]
# # Load data in hugging Face

# %%
from huggingface_hub import login, snapshot_download

# Đăng nhập bằng token của bạn
login("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")

# ID của repo trên Hugging Face (tên dataset)
repo_id = "defunct-datasets/eli5"

# Đường dẫn thư mục cục bộ nơi bạn muốn lưu dataset
local_dir = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\new"

# Tải về toàn bộ dataset từ Hugging Face
snapshot_download(repo_id=repo_id, local_dir=local_dir, repo_type="dataset")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to C:\Users\PhucT\.cache\huggingface\token
# Login successful
# Fetching 5314 files:   0%|          | 0/5314 [00:00<?, ?it/s]
# 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\new'

# %% [markdown]
# ## convert pdf

# %%
import fitz  # PyMuPDF
import os

def convert_pdfs_to_images(pdf_directory, output_directory):
    # if not os.path.exists(output_directory):
    #     os.makedirs(output_directory)
    i = 0
    for filename in os.listdir(pdf_directory):
        if filename.endswith(".pdf"):
            pdf_path = os.path.join(pdf_directory, filename)
            pdf_document = fitz.open(pdf_path)
            base_save = f"{output_directory}\\{os.path.splitext(filename)[0]}"
            if not os.path.exists(base_save):
                os.makedirs(base_save)
            
            with fitz.open(pdf_path) as pdf_document:  # Ensure the PDF is properly closed
                for page_num in range(len(pdf_document)):
                    page = pdf_document.load_page(page_num)
                    pix = page.get_pixmap()
                    image_filename = f"page_{page_num + 1}.png"
                    image_path = os.path.join(base_save, image_filename)
                    pix.save(image_path)
    print("Done")

# Thay đổi đường dẫn dưới đây theo thư mục của bạn
pdf_directory = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\new\\2008-2009 GM'
output_directory = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\new\\2008-2009 GM\\data'

convert_pdfs_to_images(pdf_directory, output_directory)
# Out:
# Done

# %% [markdown]
# ## test

# %% [markdown]
# ## resize and rename

# %%
from PIL import Image
import os

# Đường dẫn đến thư mục chứa ảnh đầu vào
input_folder = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Dewarping-Document-Image-By-Displacement-Flow-Estimation-main\\Source\\dataset\\image'
# Đường dẫn đến thư mục lưu ảnh đã resize
output_folder = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Dewarping-Document-Image-By-Displacement-Flow-Estimation-main\\Source\\dataset\\image\\resize'

# Tạo thư mục lưu ảnh đã resize nếu chưa tồn tại
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Kích thước mới của ảnh
new_size = (1024, 960)

# Lặp qua tất cả các tệp trong thư mục đầu vào và xử lý
for index, filename in enumerate(os.listdir(input_folder)):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Đọc ảnh
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path)
        
        # Resize ảnh
        img_resized = img.resize(new_size, Image.Resampling.LANCZOS)
        
        # Đổi tên file theo số thứ tự, ví dụ: 0001.png
        new_filename = f"{index+1:04d}.png"
        output_path = os.path.join(output_folder, new_filename)
        
        # Lưu ảnh đã resize và đổi tên
        img_resized.save(output_path)

        print(f'Resized and saved: {output_path}')

print('All images have been resized and renamed.')

# %% [markdown]
# ## Resize image

# %%
from PIL import Image
import os

# Đường dẫn đến thư mục chứa ảnh đầu vào
input_folder = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image\\image_xoay'
# Đường dẫn đến thư mục lưu ảnh đã resize
output_folder = 'D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image\\img_xoay'

  
# Tạo thư mục lưu ảnh đã resize nếu chưa tồn tại
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Kích thước mới của ảnh
new_size = (992, 992)  # Document-Dewarping-with-Control-Points-main 
# new_size = (1024, 960)
# Lặp qua tất cả các tệp trong thư mục đầu vào
for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        # Đọc ảnh
        img_path = os.path.join(input_folder, filename)
        img = Image.open(img_path)
        
        # Resize ảnh
        img_resized = img.resize(new_size, Image.Resampling.LANCZOS)
        
        # Lưu ảnh đã resize vào thư mục đầu ra
        output_path = os.path.join(output_folder, filename)
        img_resized.save(output_path)

        print(f'Resized and saved: {output_path}')

print('All images have been resized.')

# python test.py --data_path_test=./dataset/Hocba/image/image_xoay --parallel 0 --schema test --batch_size 1
# D:\CODE\
# Out:
# Resized and saved: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\img_xoay\0072.png
# Resized and saved: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\img_xoay\detect_boundingbox_rotated_025.jpg
# Resized and saved: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\img_xoay\detect_boundingbox_rotated_026.jpg
# Resized and saved: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\img_xoay\detect_boundingbox_rotated_027.jpg
# Resized and saved: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\img_xoay\detect_boundingbox_rotated_028.jpg
# All images have been resized.

# %%
import os

# Thư mục chứa các file ảnh
directory = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image\\image"

# Hàm đổi tên file theo số thứ tự
def rename_files_by_index(directory):
    files = [f for f in os.listdir(directory) if f.endswith(".png")]
    files.sort()  # Sắp xếp các file theo tên gốc nếu cần
    
    for index, filename in enumerate(files):
        old_file_path = os.path.join(directory, filename)
        new_filename = f"{index+1:04d}.png"  # Tạo tên mới với số thứ tự, ví dụ: 0001.png
        new_file_path = os.path.join(directory, new_filename)
        os.rename(old_file_path, new_file_path)
        print(f"Renamed: {old_file_path} -> {new_file_path}")

# Gọi hàm để đổi tên file
rename_files_by_index(directory)
# Out:
# Renamed: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\1.png -> D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\0001.png
# Renamed: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\11.png -> D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\0002.png
# Renamed: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\12.png -> D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\image\0003.png
# ...

# %%
import cv2
import numpy as np
import pytesseract
import os

# Đọc hình ảnh
img_path = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Multi-Type-TD-TSR\\Hocba\\image\\2.png"
img = cv2.imread(img_path)

# Kiểm tra nếu hình ảnh đọc được hay không
if img is None:
    print("Không thể đọc hình ảnh. Hãy kiểm tra lại đường dẫn.")
else:
    # Chuyển đổi hình ảnh sang thang độ xám
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Áp dụng adaptive threshold để làm rõ văn bản
    thresh = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)

    # Sử dụng Tesseract OCR để nhận diện văn bản
    custom_config = r'--oem 3 --psm 6'  # Tesseract config để nhận diện văn bản
    text = pytesseract.image_to_string(thresh, config=custom_config)

    print("Detected Text:")
    print(text)

    # Để xác định góc nghiêng
    def correct_skew(image):
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        coords = np.column_stack(np.where(gray > 0))
        angle = cv2.minAreaRect(coords)[-1]

        if angle < -45:
            angle = -(90 + angle)
        else:
            angle = -angle

        (h, w) = image.shape[:2]
        center = (w // 2, h // 2)
        M = cv2.getRotationMatrix2D(center, angle, 1.0)
        corrected_image = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
        
        return corrected_image

    # Sửa nghiêng của văn bản nếu cần
    corrected_img = correct_skew(img)

    # Lưu và hiển thị ảnh đã sửa
    output_dir = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Multi-Type-TD-TSR\\Hocba\\image\\out"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    output_file = os.path.join(output_dir, "corrected_image.png")
    cv2.imwrite(output_file, corrected_img)

    # Hiển thị ảnh đã sửa
    cv2.imshow("Original Image", img)
    cv2.imshow("Corrected Image", corrected_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# cd Deep_Learning/Project/ocr_ojt/Document-Image-Dewarping

# python predict.py --model_path D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Image-Dewarping\30.pt --img_path D:\CODE\Deep_Learning\Project\ocr_ojt\Multi-Type-TD-TSR\Hocba\image\2.png --save_path D:\CODE\Deep_Learning\Project\ocr_ojt\Multi-Type-TD-TSR\Hocba\image\out
# python test.py D:\CODE\Deep_Learning\Project\ocr_ojt\Multi-Type-TD-TSR\Hocba\image\4_1.png
# cd Deep_Learning/Project/ocr_ojt/DocProj
# python eval.py --imgPath .\\image\\4_1.png --modelPath \\.docProjModels\\model_geoNet.pkl --saveImgPath .\\image\\out --saveFlowPath .\\save_flow
# python test.py --data_path_test=./dataset/image/resize/
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File F:\app\envs\py\lib\site-packages\pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File F:\app\envs\py\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %% [markdown]
# ## extract paper without image

# %%
import cv2
import numpy as np

def detect_paper(image_path):
    # Đọc ảnh
    img = cv2.imread(image_path)
    
    # Chuyển sang ảnh grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Làm mịn ảnh để giảm nhiễu
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Phát hiện các cạnh (edges)
    edged = cv2.Canny(blurred, 50, 150)
    
    # Tìm các contours trong ảnh
    contours, _ = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

    # Lặp qua các contours để tìm hình dạng phù hợp
    for contour in contours:
        # Tính chu vi của contour
        peri = cv2.arcLength(contour, True)

        # Xấp xỉ các điểm của contour
        approx = cv2.approxPolyDP(contour, 0.02 * peri, True)

        # Kiểm tra xem contour có phải hình chữ nhật (4 cạnh) không
        if len(approx) == 4:
            # Vẽ hình chữ nhật xung quanh contour phát hiện được
            cv2.drawContours(img, [approx], -1, (0, 255, 0), 2)
            break

    # Hiển thị ảnh kết quả
    cv2.imshow("Detected Paper", edged)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Đường dẫn tới ảnh của bạn
df = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image\\image"
image_path = df + "\\0001.png"
detect_paper(image_path)

# %%
import cv2
import numpy as np

def detect_table_and_correct_perspective(image_path, output_path):
    # Đọc ảnh
    img = cv2.imread(image_path)
    original_img = img.copy()

    # Chuyển sang grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Làm mịn ảnh để giảm nhiễu
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Phát hiện cạnh bằng Canny
    edged = cv2.Canny(blurred, 50, 150)

    # Tìm các contours
    contours, _ = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

    # Lặp qua các contours để tìm contour hình tứ giác (đại diện cho bảng)
    table_contour = None
    for contour in contours:
        peri = cv2.arcLength(contour, True)
        approx = cv2.approxPolyDP(contour, 0.02 * peri, True)
        if len(approx) == 4:  # Tìm hình có 4 cạnh
            table_contour = approx
            break

    if table_contour is None:
        print("Không tìm thấy bảng nào trong ảnh.")
        return

    # Sắp xếp lại các điểm góc của bảng để xử lý đúng thứ tự
    pts = table_contour.reshape(4, 2)
    rect = np.zeros((4, 2), dtype="float32")

    # Tìm điểm trên cùng-trái, trên cùng-phải, dưới cùng-trái và dưới cùng-phải
    s = pts.sum(axis=1)
    rect[0] = pts[np.argmin(s)]  # Top-left
    rect[2] = pts[np.argmax(s)]  # Bottom-right

    diff = np.diff(pts, axis=1)
    rect[1] = pts[np.argmin(diff)]  # Top-right
    rect[3] = pts[np.argmax(diff)]  # Bottom-left

    # Xác định kích thước của bảng mới (sau khi sửa phối cảnh)
    (tl, tr, br, bl) = rect
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    # Tạo ma trận perspective transform
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(original_img, M, (maxWidth, maxHeight))

    # Lưu ảnh đã sửa phối cảnh
    cv2.imwrite(output_path, warped)
    print(f"Ảnh sau khi sửa phối cảnh được lưu tại: {output_path}")

# Đường dẫn tới ảnh chứa bảng và đường dẫn để lưu ảnh kết quả
df = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image"
image_path = df + "\\image\\0005.png"
output_path = df + "\\out\\0005.png"

# Chạy hàm để phát hiện bảng và sửa biến dạng phối cảnh
detect_table_and_correct_perspective(image_path, output_path)
# Out:
# Ảnh sau khi sửa phối cảnh được lưu tại: D:\CODE\Deep_Learning\Project\ocr_ojt\Document-Dewarping-with-Control-Points-main\Source\dataset\Hocba\image\out\0005.png

# %%
import cv2
import numpy as np
import math

def detect_lines_and_calculate_rotation_angle(image_path):
    # Đọc ảnh
    img = cv2.imread(image_path)
    original_img = img.copy()

    # Chuyển ảnh sang grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Sử dụng Gaussian Blur để làm mịn ảnh
    blurred = cv2.GaussianBlur(gray, (5, 5), 0)

    # Phát hiện cạnh trong ảnh bằng Canny edge detection
    edges = cv2.Canny(blurred, 50, 150)

    # Sử dụng Hough Line Transform để phát hiện các đường thẳng
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=10)

    if lines is None:
        print("Không tìm thấy đường thẳng nào.")
        return None, None

    # Tính toán góc của từng đường thẳng
    angles = []
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(original_img, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Tính toán góc của đường thẳng so với trục ngang
        angle = math.degrees(math.atan2(y2 - y1, x2 - x1))
        angles.append(angle)

    # Trung bình góc của các đường thẳng để ước lượng góc quay
    mean_angle = np.mean(angles)

    # In kết quả
    print(f"Góc trung bình của các đường thẳng: {mean_angle:.2f} độ")

    if abs(mean_angle) > 1:  # Kiểm tra xem ảnh có bị nghiêng không (góc lớn hơn 1 độ)
        print(f"Ảnh bị nghiêng {mean_angle:.2f} độ. Cần xoay để làm thẳng.")

    # Hiển thị ảnh với các đường thẳng đã phát hiện
    cv2.imshow("Detected Lines", original_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    return original_img, mean_angle

def rotate_image(img, angle):
    # Lấy kích thước của ảnh
    (h, w) = img.shape[:2]
    center = (w // 2, h // 2)

    # Tạo ma trận xoay
    M = cv2.getRotationMatrix2D(center, angle, 1.0)

    # Xoay ảnh
    rotated = cv2.warpAffine(img, M, (w, h))
    return rotated

# Đường dẫn tới ảnh
df = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\Document-Dewarping-with-Control-Points-main\\Source\\dataset\\Hocba\\image"
image_path = df + "\\image\\0001.png"

# Gọi hàm để phát hiện đường thẳng và tính góc xoay
original_img, mean_angle = detect_lines_and_calculate_rotation_angle(image_path)

# Xoay ảnh nếu cần
if original_img is not None and abs(mean_angle) > 1:
    rotated_img = rotate_image(original_img, -mean_angle)  # Xoay ngược lại góc để làm thẳng
    cv2.imshow("Rotated Image", rotated_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# Góc trung bình của các đường thẳng: -9.44 độ
# Ảnh bị nghiêng -9.44 độ. Cần xoay để làm thẳng.

# %% [markdown]
# #### 123

# %%
import os
from datetime import datetime

# # Tạo thư mục lưu trữ với timestamp
# timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
# base_save_dir = f"/content/drive/MyDrive/code/ocr/Multi_Type_TD_TSR/output/test_table/test_{timestamp}"

# # Tạo thư mục nếu chưa tồn tại
# if not os.path.exists(base_save_dir):
#     os.makedirs(base_save_dir)
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

def recognize_structure(img, save_dir):
    img_save = os.path.join(save_dir, "img.jpg")
    cv2.imwrite(img_save, img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_height, img_width = img.shape
    cv2_imshow(img)

    img_bin = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 5, 5)
    cv2_imshow(img_bin)
    # img_save = os.path.join(save_dir, "img_bin.jpg")
    # cv2.imwrite(img_save, img_bin)

    img_bin = 255 - img_bin
    plt.imshow(img_bin, cmap='gray')
    plt.show()

    kernel_len_ver = img_height // 50
    kernel_len_hor = img_width // 50
    ver_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, kernel_len_ver))
    hor_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (kernel_len_hor, 1))

    image_1 = cv2.erode(img_bin, ver_kernel, iterations=2)
    vertical_lines = cv2.dilate(image_1, ver_kernel, iterations=3)
    cv2_imshow(vertical_lines)
    # img_save = os.path.join(save_dir, "vertical_lines.jpg")
    # cv2.imwrite(img_save, vertical_lines)

    image_2 = cv2.erode(img_bin, hor_kernel, iterations=2)
    horizontal_lines = cv2.dilate(image_2, hor_kernel, iterations=3)
    cv2_imshow(horizontal_lines)
    # img_save = os.path.join(save_dir, "horizontal_lines.jpg")
    # cv2.imwrite(img_save, horizontal_lines)

    img_vh = cv2.addWeighted(vertical_lines, 0.5, horizontal_lines, 0.5, 0.0)
    cv2_imshow(img_vh)
    # img_save = os.path.join(save_dir, "combined_lines.jpg")
    # cv2.imwrite(img_save, img_vh)
    print("Kết hợp đường dọc và ngang")

    small_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (2, 2))
    img_vh = cv2.dilate(img_vh, small_kernel, iterations=1)
    cv2_imshow(img_vh)

    edges = cv2.Canny(img_vh, 50, 150, apertureSize=3)
    lines = cv2.HoughLinesP(edges, 1, np.pi / 180, threshold=100, minLineLength=100, maxLineGap=30)

    img_hough = np.copy(img_vh)
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_hough, (x1, y1), (x2, y2), (255, 0, 0), 2)

    cv2_imshow(img_hough)
    # img_save = os.path.join(save_dir, "hough_lines_detected.jpg")
    # cv2.imwrite(img_save, img_hough)
    print("Vẽ các đường nghiêng lên ảnh")

    bitxor = cv2.bitwise_xor(img, img_hough)
    bitnot = cv2.bitwise_not(bitxor)
    cv2_imshow(bitnot)
    # img_save = os.path.join(save_dir, "bitnot_image.jpg")
    # cv2.imwrite(img_save, bitnot)

    edges_bitnot = cv2.Canny(bitnot, 50, 150, apertureSize=3)
    lines_bitnot = cv2.HoughLinesP(edges_bitnot, 1, np.pi / 180, threshold=100, minLineLength=150, maxLineGap=30)

    img_bitnot_hough = np.copy(bitnot)
    if lines_bitnot is not None:
        for line in lines_bitnot:
            x1, y1, x2, y2 = line[0]
            cv2.line(img_bitnot_hough, (x1, y1), (x2, y2), (0, 255, 0), 2)

    cv2_imshow(img_bitnot_hough)
    # img_save = os.path.join(save_dir, "bitnot_hough_lines_detected.jpg")
    # cv2.imwrite(img_save, img_bitnot_hough)

    contours, hierarchy = cv2.findContours(img_hough, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    def sort_contours(cnts, method="left-to-right"):
        reverse = False
        i = 0
        if method == "right-to-left" or method == "bottom-to-top":
            reverse = True
        if method == "top-to-bottom" or method == "bottom-to-top":
            i = 1
        boundingBoxes = [cv2.boundingRect(c) for c in cnts]
        (cnts, boundingBoxes) = zip(*sorted(zip(cnts, boundingBoxes), key=lambda b: b[1][i], reverse=reverse))
        return (cnts, boundingBoxes)

    contours, boundingBoxes = sort_contours(contours, method="top-to-bottom")
    heights = [boundingBoxes[i][3] for i in range(len(boundingBoxes))]
    mean = np.mean(heights)

    box = []
    for c in contours:
        x, y, w, h = cv2.boundingRect(c)
        if (w < 0.9 * img_width and h < 0.9 * img_height):
            image = cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
            box.append([x, y, w, h])

    cv2_imshow(image)
    # img_save = os.path.join(save_dir, "contours_detected.jpg")
    # cv2.imwrite(img_save, image)

    return box, img_bin

def create_mask_for_tables(img, boxes, min_width=150, min_height=150):
    """
    Tạo mặt nạ cho các bảng đã được trích xuất nếu bảng đủ điều kiện.
    """
    mask = np.zeros_like(img, dtype=np.uint8)

    for (x, y, w, h) in boxes:
        if w > min_width and h > min_height:
            cv2.rectangle(mask, (x, y), (x + w, y + h), (255, 255, 255), thickness=cv2.FILLED)

    return mask

def remove_tables_from_image(img, mask):
    """
    Loại bỏ các bảng khỏi ảnh gốc bằng cách sử dụng mặt nạ.
    """
    mask_inv = cv2.bitwise_not(mask)
    img_no_tables = cv2.bitwise_and(img, mask_inv)

    return img_no_tables

def extract_and_save_tables(img, boxes, base_save_dir, min_width=150, min_height=150):
    if not os.path.exists(base_save_dir):
        os.makedirs(base_save_dir)

    mask = create_mask_for_tables(img, boxes)

    img_mask = np.copy(img)

    cv2.imwrite(os.path.join(base_save_dir, "img_mask.jpg"), mask)

    img_no_tables = remove_tables_from_image(img, mask)
    cv2.imwrite(os.path.join(base_save_dir, "img_no_tables.jpg"), img_no_tables)

    coords_file = os.path.join(base_save_dir, "table_coords.txt")

    with open(coords_file, "w") as f:
        for i, (x, y, w, h) in enumerate(boxes):
            table_img = img[y:y+h, x:x+w]
            if w > min_width and h > min_height:
                table_filename = os.path.join(base_save_dir, f"table_{i+1}.jpg")
                cv2.imwrite(table_filename, table_img)
                print(f"Đã lưu bảng {i+1} vào {table_filename}")

                f.write(f"table_{i+1}.jpg {x} {y} {w} {h}\n")
            else:
                print(f"Bảng {i+1} có kích thước quá nhỏ và không được lưu.")

    print(f"Tọa độ của các bảng đã được lưu vào {coords_file}")

# def extract_and_save_tables(img, boxes, base_save_dir, min_width=100, min_height=100):
#     if not os.path.exists(base_save_dir):
#         os.makedirs(base_save_dir)

#     coords_file = os.path.join(base_save_dir, "table_coords.txt")

#     with open(coords_file, "w") as f:
#         for i, (x, y, w, h) in enumerate(boxes):
#             table_img = img[y:y+h, x:x+w]
#             if w > min_width and h > min_height:
#                 table_filename = os.path.join(base_save_dir, f"table_{i+1}.jpg")
#                 cv2.imwrite(table_filename, table_img)
#                 print(f"Đã lưu bảng {i+1} vào {table_filename}")

#                 # Lưu tọa độ của table vào file text
#                 f.write(f"table_{i+1}.jpg {x} {y} {w} {h}\n")
#             else:
#                 print(f"Bảng {i+1} có kích thước quá nhỏ và không được lưu.")

#     print(f"Tọa độ của các bảng đã được lưu vào {coords_file}")


def recognize_text_in_folder(folder_path, model, result_save_dir):
    """
    Thực hiện nhận diện văn bản cho tất cả các bảng trong folder và lưu kết quả.
    """
    # Duyệt qua tất cả các file trong thư mục
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        if filename.endswith(".jpg"):
            # Đọc ảnh
            image = cv2.imread(file_path)
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            # Thực hiện nhận diện văn bản
            result_image = create_result(image, model, device="cpu")  # Gọi hàm nhận diện văn bản

            # Xác định tên ảnh kết quả
            if filename == "img.jpg":
                result_filename = "img_recognized.jpg"
            else:
                result_filename = filename.replace("table_", "result_table_")

            # Lưu kết quả nhận diện với tên phù hợp
            result_path = os.path.join(result_save_dir, result_filename)
            cv2.imwrite(result_path, cv2.cvtColor(result_image, cv2.COLOR_RGB2BGR))
            print(f"Đã lưu kết quả nhận diện: {result_path}")


# Bước 3: Ghép lại các bảng đã nhận diện vào ảnh có tên là 'img.jpg'
def reassemble_tables_with_recognized_text_to_img(img_folder_path, table_folder_path):
    """
    Ghép các bảng đã nhận diện vào ảnh có tên là 'img.jpg' trong thư mục.
    """
    coords_file = os.path.join(table_folder_path, "table_coords.txt")

    # Đọc file chứa tọa độ của các bảng
    with open(coords_file, "r") as f:
        lines = f.readlines()

    img_path = os.path.join(img_folder_path, "img_no_tables.jpg")  # Đường dẫn tới ảnh có tên 'img.jpg' img_recognized.jpg
    img = cv2.imread(img_path)

    # Ghép lại các bảng đã nhận diện vào vị trí ban đầu
    for line in lines:
        table_file, x, y, w, h = line.split()
        x, y, w, h = int(x), int(y), int(w), int(h)

        # Đọc lại bảng đã nhận diện (result_table_x.jpg)
        result_table_path = os.path.join(table_folder_path, table_file.replace("table_", "result_table_"))
        result_table_img = cv2.imread(result_table_path)

        # Ghép lại bảng vào ảnh 'img.jpg'
        img[y:y+h, x:x+w] = result_table_img
        print(f"Ghép lại bảng {result_table_path} vào vị trí ({x}, {y}, {w}, {h}) trên ảnh img.jpg")

    # Lưu ảnh sau khi ghép lại
    result_img_path = os.path.join(img_folder_path, "final_img_with_tables.jpg")
    cv2.imwrite(result_img_path, img)
    print(f"Ảnh img_recognized.jpg đã được ghép lại và lưu tại: {result_img_path}")

# %%
import os
import cv2
from datetime import datetime

df = "D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\test_table\\test_20240917_090806\\"
name = "0008.png"
bordered_table = cv2.imread(df + name)  # Đọc hình ảnh từ file

# Không cần đọc lại hình ảnh từ `bordered_table`
# Sử dụng trực tiếp `bordered_table` (là một mảng numpy)
bordered_table = cv2.cvtColor(bordered_table, cv2.COLOR_BGR2RGB)  # Chuyển đổi màu sắc sang RGB

# Tạo thư mục lưu trữ với dấu thời gian
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
base_save_dir = f"D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\data\\new_test\\test_{timestamp}"  # _{name}

# Kiểm tra và tạo thư mục lưu nếu chưa tồn tại
if not os.path.exists(base_save_dir):
    os.makedirs(base_save_dir)

# Khởi tạo danh sách chứa các bounding box của bảng
list_table_boxes = []
table_list = [bordered_table]

# Duyệt qua danh sách bảng để nhận diện cấu trúc và lưu lại
for table in table_list:
    finalboxes, output_img = recognize_structure(table, base_save_dir)
    list_table_boxes.append(finalboxes)
    extract_and_save_tables(bordered_table, finalboxes, base_save_dir)  # Hàm để tách và lưu bảng

# Nhận diện văn bản từ các bảng đã lưu
recognize_text_in_folder(base_save_dir, model_craft, model_ocr, base_save_dir)

# Ghép lại bảng đã nhận diện vào ảnh gốc
reassemble_tables_with_recognized_text_to_img(base_save_dir, base_save_dir)

# %%
import torch
import numpy as np
from PIL import Image, ImageDraw, ImageFont
import cv2
import numpy as np
from CRAFT import CRAFTModel, draw_boxes, draw_polygons, boxes_area, polygons_area
import gc
model_craft = CRAFTModel('weights/', 'cuda:0', use_refiner=True, fp16=True)


def get_detected_bbox_craft(image, craft_model, device="cpu"):
    image = np.array(image)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    with torch.no_grad():
        bboxes = craft_model.get_boxes(image)

    return bboxes


def draw_bbox(img, bboxes, color=(255, 0, 0), thickness=2):
    img = img.copy()
    draw = ImageDraw.Draw(img)
    for bbox in bboxes:
        minx, miny = int(min(bbox[:, 0])), int(min(bbox[:, 1]))
        maxx, maxy = int(max(bbox[:, 0])), int(max(bbox[:, 1]))
        draw.rectangle([minx, miny, maxx, maxy], outline=color, width=thickness)
    return img

def get_min_max_pos(bbox):
    bbox = np.array(bbox)  
    minx = int(min(bbox[:, 0]))
    maxx = int(max(bbox[:, 0]))
    miny = int(min(bbox[:, 1]))
    maxy = int(max(bbox[:, 1]))

    return minx, miny, maxx, maxy


def get_cropped_area(image, bbox):
    minx, miny, maxx, maxy = get_min_max_pos(bbox)
    return image.crop((minx, miny, maxx, maxy))


def recog_and_draw(image, bboxes, model_ocr, font_path="D:\\CODE\\Deep_Learning\\Project\\ocr_ojt\\viet2\\vietocr\\Arial.ttf", device="cuda:0"):  # Roboto-Regular.ttf
    torch.cuda.empty_cache()
    gc.collect()
    if isinstance(image, np.ndarray):
        image = Image.fromarray(image)

    try:
        font = ImageFont.truetype(font_path, 16) 
    except IOError:
        print(f"Không tìm thấy font tại {font_path}. Sử dụng font mặc định.")
        font = ImageFont.load_default()

    draw = ImageDraw.Draw(image)


    for bbox in bboxes:
        cropped_image = get_cropped_area(image, bbox)
        pred_text = model_ocr.predict(cropped_image)


        minx, miny, maxx, maxy = get_min_max_pos(bbox)


        draw.rectangle([minx, miny, maxx, maxy], outline="red", width=2)
        draw.text((minx, miny - 10), pred_text, fill="blue", font=font)

    return image


def create_result(image, model_craft, model_ocr, device="cuda:0"):

    bboxes = get_detected_bbox_craft(image, model_craft, device=device)


    result_image = recog_and_draw(image, bboxes, model_ocr, device=device)

    return result_image
